# %%
import os

# %%
path = 'D:/BigData/datasets/ILSVRC2017_DET/ILSVRC/Data/DET/train'

os.listdir(path)
# Out:
# ['ILSVRC2013_train',
#  'ILSVRC2013_train_extra0',
#  'ILSVRC2013_train_extra0.tar',
#  'ILSVRC2013_train_extra1',
#  'ILSVRC2013_train_extra1.tar',
#  'ILSVRC2013_train_extra10',
#  'ILSVRC2013_train_extra2',
#  'ILSVRC2013_train_extra3',
#  'ILSVRC2013_train_extra4',
#  'ILSVRC2013_train_extra5',
#  'ILSVRC2013_train_extra6',
#  'ILSVRC2013_train_extra7',
#  'ILSVRC2013_train_extra8',
#  'ILSVRC2013_train_extra9',
#  'ILSVRC2014_train_0000',
#  'ILSVRC2014_train_0001',
#  'ILSVRC2014_train_0002',
#  'ILSVRC2014_train_0003',
#  'ILSVRC2014_train_0004',
#  'ILSVRC2014_train_0005',
#  'ILSVRC2014_train_0006']

# %%
os.listdir(os.path.join(path, 'ILSVRC2013_train'))
# Out:
# ['n00007846',
#  'n00141669',
#  'n00477639',
#  'n01443537',
#  'n01495701',
#  'n01496331',
#  'n01498041',
#  'n01503061',
#  'n01514668',
#  'n01514859',
#  'n01518878',
#  'n01530575',
#  'n01531178',
#  'n01532829',
#  'n01534433',
#  'n01537544',
#  'n01558993',
#  'n01560419',
#  'n01580077',
#  'n01582220',
#  'n01592084',
#  'n01601694',
#  'n01608432',
#  'n01614925',
#  'n01616318',
#  'n01622779',
#  'n01639765',
#  'n01641577',
#  'n01644373',
#  'n01644900',
#  'n01662784',
#  'n01664065',
#  'n01665541',
#  'n01667114',
#  'n01667778',
#  'n01669191',
#  'n01674464',
#  'n01675722',
#  'n01677366',
#  'n01682714',
#  'n01685808',
#  'n01687978',
#  'n01688243',
#  'n01689811',
#  'n01692333',
#  'n01693334',
#  'n01694178',
#  'n01695060',
#  'n01726692',
#  'n01728572',
#  'n01728920',
#  'n01729322',
#  'n01729977',
#  'n01734418',
#  'n01735189',
#  'n01737021',
#  'n01739381',
#  'n01740131',
#  'n01742172',
#  'n01744401',
#  'n01748264',
#  'n01749939',
# ...

# %%
os.listdir(os.path.join(path, 'ILSVRC2013_train', 'n00007846'))
# Out:
# ['n00007846_103856.JPEG',
#  'n00007846_104163.JPEG',
#  'n00007846_104414.JPEG',
#  'n00007846_105689.JPEG',
#  'n00007846_106069.JPEG',
#  'n00007846_107024.JPEG',
#  'n00007846_109518.JPEG',
#  'n00007846_109796.JPEG',
#  'n00007846_110945.JPEG',
#  'n00007846_111865.JPEG',
#  'n00007846_112303.JPEG',
#  'n00007846_112420.JPEG',
#  'n00007846_112441.JPEG',
#  'n00007846_113696.JPEG',
#  'n00007846_113796.JPEG',
#  'n00007846_114027.JPEG',
#  'n00007846_114285.JPEG',
#  'n00007846_114327.JPEG',
#  'n00007846_114475.JPEG',
#  'n00007846_115177.JPEG',
#  'n00007846_115252.JPEG',
#  'n00007846_115428.JPEG',
#  'n00007846_115843.JPEG',
#  'n00007846_115962.JPEG',
#  'n00007846_116320.JPEG',
#  'n00007846_116564.JPEG',
#  'n00007846_116792.JPEG',
#  'n00007846_118082.JPEG',
#  'n00007846_118989.JPEG',
#  'n00007846_120456.JPEG',
#  'n00007846_121993.JPEG',
#  'n00007846_122290.JPEG',
#  'n00007846_122364.JPEG',
#  'n00007846_122733.JPEG',
#  'n00007846_123555.JPEG',
# ...

# %%
os.listdir(os.path.join(path, 'ILSVRC2013_train_extra0'))
# Out:
# ['ILSVRC2013_train_00000001.JPEG',
#  'ILSVRC2013_train_00000002.JPEG',
#  'ILSVRC2013_train_00000003.JPEG',
#  'ILSVRC2013_train_00000004.JPEG',
#  'ILSVRC2013_train_00000005.JPEG',
#  'ILSVRC2013_train_00000006.JPEG',
#  'ILSVRC2013_train_00000007.JPEG',
#  'ILSVRC2013_train_00000008.JPEG',
#  'ILSVRC2013_train_00000009.JPEG',
#  'ILSVRC2013_train_00000010.JPEG',
#  'ILSVRC2013_train_00000011.JPEG',
#  'ILSVRC2013_train_00000012.JPEG',
#  'ILSVRC2013_train_00000013.JPEG',
#  'ILSVRC2013_train_00000014.JPEG',
#  'ILSVRC2013_train_00000015.JPEG',
#  'ILSVRC2013_train_00000016.JPEG',
#  'ILSVRC2013_train_00000017.JPEG',
#  'ILSVRC2013_train_00000018.JPEG',
#  'ILSVRC2013_train_00000019.JPEG',
#  'ILSVRC2013_train_00000020.JPEG',
#  'ILSVRC2013_train_00000021.JPEG',
#  'ILSVRC2013_train_00000022.JPEG',
#  'ILSVRC2013_train_00000023.JPEG',
#  'ILSVRC2013_train_00000024.JPEG',
#  'ILSVRC2013_train_00000025.JPEG',
#  'ILSVRC2013_train_00000026.JPEG',
#  'ILSVRC2013_train_00000027.JPEG',
# ...
